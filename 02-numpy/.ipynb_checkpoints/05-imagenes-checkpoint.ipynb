# %%
import numpy as np
from scipy import ndimage
from scipy import miscmap

# %%
mapache= misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
mapache.shape # dimension
# Out:
# (768, 1024, 3)

# %%
type(mapache)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
mapache1=mapache[::-1]

# %%
plt.imshow(mapache1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imshow(mapache1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
arr1, arr2 = np.vsplit(mapache,2)
print(arr1)
print(arr2)
# Out:
# [[[121 112 131]
#   [138 129 148]
#   [153 144 165]
#   ...
#   [119 126  74]
#   [131 136  82]
#   [139 144  90]]
#
#  [[ 89  82 100]
#   [110 103 121]
#   [130 122 143]
#   ...
#   [118 125  71]
#   [134 141  87]
#   [146 153  99]]
#
#  [[ 73  66  84]
#   [ 94  87 105]
#   [115 108 126]
#   ...
#   [117 126  71]
#   [133 142  87]
#   [144 153  98]]
#
#  ...
#
#  [[203 233 111]
#   [198 228 106]
#   [191 223  98]
#   ...
#   [ 24  36  16]
#   [ 25  37  17]
#   [ 25  37  17]]
#
#  [[203 233 109]
#   [198 228 104]
#   [191 223  96]
#   ...
#   [ 24  36  16]
#   [ 25  37  17]
#   [ 25  37  17]]
#
#  [[195 225 101]
#   [194 226  99]
#   [193 225  98]
#   ...
#   [ 24  36  16]
#   [ 25  37  17]
#   [ 25  37  17]]]
# [[[187 220  87]
#   [183 216  85]
#   [183 213  89]
#   ...
#   [ 28  37  20]
#   [ 29  38  21]
#   [ 29  38  21]]
#
#  [[186 222  88]
#   [184 217  86]
#   [182 213  86]
#   ...
#   [ 26  35  18]
#   [ 27  36  19]
#   [ 27  36  19]]
#
#  [[188 224  90]
#   [186 222  90]
# ...

# %%
plt.imshow(arr1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imshow(arr2)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
arr3, arr4 = np.hsplit(arr1,2)
print(arr3)
print(arr4)
# Out:
# [[[121 112 131]
#   [138 129 148]
#   [153 144 165]
#   ...
#   [158 144 144]
#   [158 144 144]
#   [151 137 137]]
#
#  [[ 89  82 100]
#   [110 103 121]
#   [130 122 143]
#   ...
#   [159 145 145]
#   [159 145 145]
#   [149 135 135]]
#
#  [[ 73  66  84]
#   [ 94  87 105]
#   [115 108 126]
#   ...
#   [168 154 154]
#   [171 157 157]
#   [160 146 146]]
#
#  ...
#
#  [[203 233 111]
#   [198 228 106]
#   [191 223  98]
#   ...
#   [ 84  86  99]
#   [ 85  87 100]
#   [ 89  91 104]]
#
#  [[203 233 109]
#   [198 228 104]
#   [191 223  96]
#   ...
#   [ 65  67  82]
#   [ 70  72  87]
#   [ 79  81  94]]
#
#  [[195 225 101]
#   [194 226  99]
#   [193 225  98]
#   ...
#   [ 82  84  99]
#   [ 87  89 104]
#   [ 95  97 112]]]
# [[[111 102 103]
#   [112 103 104]
#   [126 117 118]
#   ...
#   [119 126  74]
#   [131 136  82]
#   [139 144  90]]
#
#  [[111 101 102]
#   [107  97  98]
#   [116 106 107]
#   ...
#   [118 125  71]
#   [134 141  87]
#   [146 153  99]]
#
#  [[116 106 107]
#   [110 100 101]
# ...

# %%
plt.imshow(arr3)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imshow(arr4)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
arr5, arr6 = np.hsplit(arr2,2)
print(arr5)
print(arr6)
# Out:
# [[[187 220  87]
#   [183 216  85]
#   [183 213  89]
#   ...
#   [124 127 146]
#   [113 116 133]
#   [107 110 127]]
#
#  [[186 222  88]
#   [184 217  86]
#   [182 213  86]
#   ...
#   [172 175 192]
#   [163 166 181]
#   [158 161 176]]
#
#  [[188 224  90]
#   [186 222  90]
#   [183 215  88]
#   ...
#   [187 190 205]
#   [191 195 207]
#   [193 197 209]]
#
#  ...
#
#  [[ 87 106  76]
#   [ 94 110  81]
#   [107 124  92]
#   ...
#   [ 93 132  77]
#   [ 93 132  77]
#   [ 93 132  77]]
#
#  [[ 85 101  72]
#   [ 95 111  82]
#   [112 127  96]
#   ...
#   [ 95 134  79]
#   [ 94 133  78]
#   [ 94 133  78]]
#
#  [[ 85 101  74]
#   [ 97 113  84]
#   [111 126  97]
#   ...
#   [ 96 135  80]
#   [ 96 135  80]
#   [ 96 135  80]]]
# [[[103  99 114]
#   [106 104 118]
#   [114 112 126]
#   ...
#   [ 28  37  20]
#   [ 29  38  21]
#   [ 29  38  21]]
#
#  [[116 113 130]
#   [100  97 114]
#   [ 84  81  98]
#   ...
#   [ 26  35  18]
#   [ 27  36  19]
#   [ 27  36  19]]
#
#  [[162 159 178]
#   [167 164 183]
# ...

# %%
plt.imshow(arr5)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imshow(arr6)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imshow(mapache, cmap=plt.cm.gray, vmin=0, vmax=0)

# %%
plt.imshow(mapache, cmap=plt.cm.gray)

# %%
mapache.max(), mapache.min()
# Out:
# (255, 0)

# %%
 rotate_mapache = ndimage.rotate(mapache, 45)

# %%
plt.imshow(rotate_mapache)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
blurred_mapache = ndimage.gaussian_filter(mapache, sigma=3)
very_blurred = ndimage.gaussian_filter(mapache, sigma=5)
local_mean = ndimage.uniform_filter(mapache, size=11)

# %%
plt.imshow(blurred_mapache)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imshow(very_blurred)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.imshow(local_mean)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
mapache_rojo=np.copy(mapache) # creo una copia de la imagen para preservar la original
mapache_rojo[:,:,1]=0
mapache_rojo[:,:,2]=0
plt.imshow(mapache_rojo)

# %%
mapache_red_green=np.copy(mapache) # creo una copia de la imagen para preservar la original
mapache_red_green[:,:,2]=0
plt.imshow(mapache_red_green)
